# %% [markdown]
# # SwasthyaSahayak — Capstone Demo Notebook
#
# Demo notebook for the SwasthyaSahayak multi-agent system. Uses a MockLLM for offline runnable examples.

# %%
from swasthya.agents.symptom_agent import run_symptom_agent
from swasthya.agents.inventory_agent import run_inventory_agent

case = {'age':45,'gender':'male','complaint':'Shortness of breath and chest tightness starting today.'}
print(run_symptom_agent(case))

print('\nInventory demo:')
print(run_inventory_agent('data/raw/sample_inventory.csv')['report_table'].head())
